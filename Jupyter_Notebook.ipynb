# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ***Gangmin Choe***

# %% [markdown]
# 100% Human

# %% [markdown]
# *I am interested in data science because I love to figure out relationship between data.*

# %% [markdown]
# ### The following code load Apple stock price data and provide the close price line chart.

# %%
import numpy as np 
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# !pip install -U finance-datareader

import FinanceDataReader as fdr

df = fdr.DataReader('AAPL', '2012-01-01', '2022-12-31')

# Plot the close price line chart
plt.plot(df['Close'])
plt.title('Apple Stock Close Price Line Plot')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.show()

# %% [markdown]
# ***
# **More information**

# %% [markdown]
# [Apple Stock Info.](https://finance.yahoo.com/quote/AAPL/)

# %% [markdown]
# > As I did above, we can use simple data science tool to analyze and visualize the stock information too.
